# %%
import networkx as nx

# %%
ver,ed = map(int,input('Enter Vertices and Edges:  ').split())
details = {}

# %%
for i in range(ed):
    u,v,w = map(int,input('U,v & weight: ').split())
    details[u,v] = w
details
# Out:
# {(1, 3): 4, (1, 2): 3, (2, 4): 3, (3, 5): 1, (2, 5): 2}

# %%
nodes = []
edges = []
for i,pair in enumerate(details.keys()):
    for j,node in enumerate(pair):
        if node not in nodes:
            nodes.append(node)
nodes

edges = details.keys()
weights = details.values()
G = nx.Graph()
G.add_nodes_from (nodes)
G.add_edges_from(edges)
G.add_weighted_edges_from()
nx.draw(G, with_labels =True)

# %%
current = 1
visited = []
    
for i,j in enumerate(details.keys()):
    val = []
    visited.append(current)
    if j[0] == current:    
        val.append(details[pair])
    print(min(val))
# Out:
# 3
# 3
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[104], line 9
#       7 if j[0] == current:
#       8     val.append(details[pair])
# ----> 9 print(min(val))
#
# ValueError: min() arg is an empty sequence
